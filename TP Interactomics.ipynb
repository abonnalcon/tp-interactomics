# %%
import requests
import pandas as pd

# %%
url = "http://www.ebi.ac.uk/Tools/webservices/psicquic/intact/webservices/current/search/query/pubid:17446270"

try:
    httpReq = requests.get(url, proxies=None)
except NameError:
    httpReq = requests.get(url)
ans = httpReq.text

# %%
#1 | Unique identifier for interactor A
#2 | Unique identifier for interactor B
#3 | Alternative identifier for interactor A
#4 | Alternative identifier for interactor B
#5 | Aliases for A
#6 | Aliases for B
#7 | Interaction detection methods
#9 | Publication Identifier(s)
#11| Interaction types
#15| Confidence score
df = pd.DataFrame([x.split("\t") for x in ans.split('\n')])
df = df.drop([232])
df.tail()
# Out:
#                    0                   1   \
# 227  uniprotkb:P62995    uniprotkb:Q3KSU1
# 228  uniprotkb:Q3KSU1    uniprotkb:Q68DS7
# 229  uniprotkb:P0C729    uniprotkb:Q08380
# 230  uniprotkb:Q3KSU1  intact:EBI-2623792
# 231  uniprotkb:P0C722    uniprotkb:Q12933
#
#                                                     2   \
# 227  intact:EBI-725485|uniprotkb:B4DVK2|uniprotkb:D...
# 228                intact:EBI-2621113|uniprotkb:Q3KSU0
# 229                                 intact:EBI-2621229
# 230                intact:EBI-2621113|uniprotkb:Q3KSU0
# 231                intact:EBI-2623029|uniprotkb:Q777E3
#
#                                                     3   \
# 227                intact:EBI-2621113|uniprotkb:Q3KSU0
# 228                                 intact:EBI-2623779
# 229  intact:EBI-354956|uniprotkb:Q9UCH8|uniprotkb:Q...
# 230                                                  -
# 231  intact:EBI-355744|uniprotkb:A8K107|uniprotkb:B...
#
#                                                     4   \
# 227  psi-mi:tra2b_human(display_long)|uniprotkb:TRA...
# 228  psi-mi:icp27_ebvg(display_long)|uniprotkb:Prot...
# 229  psi-mi:lmp2_ebvg(display_long)|uniprotkb:LMP2(...
# 230  psi-mi:icp27_ebvg(display_long)|uniprotkb:Prot...
# 231  psi-mi:brrf1_ebvg(display_long)|uniprotkb:BRRF...
#
#                                                     5   \
# 227  psi-mi:icp27_ebvg(display_long)|uniprotkb:Prot...
# 228  psi-mi:q68ds7_human(display_long)|uniprotkb:DK...
# 229  psi-mi:lg3bp_human(display_long)|uniprotkb:Lec...
# 230  psi-mi:gg6l8_human(display_short)|psi-mi:EBI-2...
# 231  psi-mi:traf2_human(display_long)|uniprotkb:Tum...
#
#                                6                         7   \
# 227  psi-mi:"MI:0018"(two hybrid)  Calderwood et al. (2007)
# 228  psi-mi:"MI:0018"(two hybrid)  Calderwood et al. (2007)
# 229  psi-mi:"MI:0018"(two hybrid)  Calderwood et al. (2007)
# 230  psi-mi:"MI:0018"(two hybrid)  Calderwood et al. (2007)
# 231  psi-mi:"MI:0018"(two hybrid)  Calderwood et al. (2007)
#
#                                                   8   \
# 227  pubmed:17446270|imex:IM-20435|mint:MINT-6769080
# 228  pubmed:17446270|imex:IM-20435|mint:MINT-6769080
# 229  pubmed:17446270|imex:IM-20435|mint:MINT-6769080
# 230  pubmed:17446270|imex:IM-20435|mint:MINT-6769080
# 231  pubmed:17446270|imex:IM-20435|mint:MINT-6769080
#
#                                                     9   \
# 227         taxid:9606(human)|taxid:9606(Homo sapiens)
# 228  taxid:10376(ebvg)|taxid:10376("Epstein-Barr vi...
# 229  taxid:10376(ebvg)|taxid:10376("Epstein-Barr vi...
# 230  taxid:10376(ebvg)|taxid:10376("Epstein-Barr vi...
# 231  taxid:10376(ebvg)|taxid:10376("Epstein-Barr vi...
#
#                                                     10  \
# 227  taxid:10376(ebvg)|taxid:10376("Epstein-Barr vi...
# 228         taxid:9606(human)|taxid:9606(Homo sapiens)
# 229         taxid:9606(human)|taxid:9606(Homo sapiens)
# 230         taxid:9606(human)|taxid:9606(Homo sapiens)
# 231         taxid:9606(human)|taxid:9606(Homo sapiens)
#
#                                          11                        12  \
# 227  psi-mi:"MI:0915"(physical association)  psi-mi:"MI:0469"(IntAct)
# 228  psi-mi:"MI:0915"(physical association)  psi-mi:"MI:0469"(IntAct)
# 229  psi-mi:"MI:0915"(physical association)  psi-mi:"MI:0469"(IntAct)
# 230  psi-mi:"MI:0915"(physical association)  psi-mi:"MI:0469"(IntAct)
# 231  psi-mi:"MI:0915"(physical association)  psi-mi:"MI:0469"(IntAct)
#
#                                        13                   14
# 227  intact:EBI-2623770|imex:IM-20435-227  intact-miscore:0.37
# 228  intact:EBI-2623783|imex:IM-20435-228  intact-miscore:0.37
# 229  intact:EBI-2623752|imex:IM-20435-225  intact-miscore:0.37
# 230  intact:EBI-2623795|imex:IM-20435-229  intact-miscore:0.37
# 231  intact:EBI-2644156|imex:IM-20435-230  intact-miscore:0.37

# %%
df[0][1].startswith("uniprot")
# Out:
# True

# %%
ans_list = ans.split("\n")

indexNames = df[df[0].startswith("uniprot")].index
df.drop(indexNames, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-626346e3cfc2> in <module>
#       1 ans_list = ans.split("\n")
#       2
# ----> 3 indexNames = df[df[0].startswith("uniprot")].index
#       4 #dfObj.drop(indexNames , inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'startswith'

# %%
# recupérer les lignes où les interactants sont des identifiants Uniprot
ans_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-2c90698e6be7> in <module>
#       1 # recupérer les lignes où les interactants sont des identifiants Uniprot
# ----> 2 df_Uniprot = df.loc[df[0].startwith("uniprot")==T]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'startwith'
